# %%
import datetime

# %%
b = [1,2,3]

# %%
# ?b

# %%
import numpy as np

# %%
np.*load*?

# %%
# %pwd
# Out:
# '/Users/sangsang/Desktop/tensorflow/tensorflow'

# %%
foo = %pwd

# %%
foo
# Out:
# '/Users/sangsang/Desktop/tensorflow/tensorflow'

# %%
# %quickref

# %%
# %magic

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.plot(np.random.randn(50).cumsum())
